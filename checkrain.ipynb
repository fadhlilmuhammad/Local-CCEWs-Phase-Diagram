# %%
import xarray as xr
import numpy as np
# import cartopy as c

# %%
ds = xr.open_dataset("data/precip/agcd_v1_precip_calib_r005_1980-2019.regrid.land.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 14610, bnds: 2, lon: 177, lat: 138)
# Coordinates:
#   * time       (time) datetime64[ns] 1980-01-01T09:00:00 ... 2019-12-31T09:00:00
#   * lon        (lon) float32 112.0 112.2 112.5 112.8 ... 155.2 155.5 155.8 156.0
#   * lat        (lat) float32 -44.5 -44.25 -44.0 -43.75 ... -10.75 -10.5 -10.25
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     precip     (time, lat, lon) float32 ...
# Attributes: (12/35)
#     CDI:                       Climate Data Interface version 2.1.0 (https://...
#     source:                    Data is from site-based observation data recor...
#     institution:               Australian Bureau of Meteorology, GPO Box 1289...
#     Conventions:               CF-1.6, ACDD-1.3
#     geospatial_lat_min:        -44.525
#     geospatial_lat_max:        -9.975
#     ...                        ...
# ...

# %%
prec = ds["precip"].sel(time=slice('2015-12-02','2015-12-23'),lat=slice(-13,-10),lon=slice(129,131))
prec
# Out:
# <xarray.DataArray 'precip' (time: 22, lat: 12, lon: 9)>
# array([[[      nan,       nan, ...,  6.942274,  6.08046 ],
#         [      nan,       nan, ...,  6.19332 ,  5.064014],
#         ...,
#         [      nan,       nan, ...,       nan,       nan],
#         [      nan,       nan, ...,       nan,       nan]],
#
#        [[      nan,       nan, ...,  6.007742,  4.889372],
#         [      nan,       nan, ...,  4.402233,  4.005059],
#         ...,
#         [      nan,       nan, ...,       nan,       nan],
#         [      nan,       nan, ...,       nan,       nan]],
#
#        ...,
#
#        [[      nan,       nan, ..., 18.598757, 18.611296],
#         [      nan,       nan, ..., 21.947655, 20.222471],
#         ...,
#         [      nan,       nan, ...,       nan,       nan],
#         [      nan,       nan, ...,       nan,       nan]],
#
#        [[      nan,       nan, ..., 22.518179, 22.429956],
#         [      nan,       nan, ..., 24.078865, 19.208275],
#         ...,
# ...

# %%
max_val = prec.max()
qt_values = (0.99)

prec_qt = prec.quantile(qt_values,dim=["lat","lon"])
prec_qt

# prec.where(prec==prec.quantile(,dim=["lat","lon"]), drop=True).squeeze()
# Out:
# <xarray.DataArray 'precip' (time: 14610)>
# array([55.5314188 , 69.6366272 , 46.47346592, ..., 28.25767851,
#        23.20474052, 15.78234577])
# Coordinates:
#   * time      (time) datetime64[ns] 1980-01-01T09:00:00 ... 2019-12-31T09:00:00
#     quantile  float64 0.99

# %%
prec.to_netcdf("raincheck.nc")
