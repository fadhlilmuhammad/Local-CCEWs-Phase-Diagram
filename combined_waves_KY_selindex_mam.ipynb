# %%
import xarray as xr
import pandas as pd
import numpy as np

# %%
diri = "/Users/fadhlilrizki/Documents/PhD/thesis/dataout/local_wave_phase/"
diro = "/Users/fadhlilrizki/Documents/PhD/thesis/dataout/local_wave_phase/combined_wave/"

# %%
fw_1 = "local_er_phase_SHAutumn.133.nc"
fw_2 = "local_kelvin_phase_SHAutumn.133.nc"
fw_3 = "local_mrg_phase_SHAutumn.133.nc"
fw_4 = "local_td_phase_SHAutumn.133.nc"
fw_5 = "local_mjo_phase_SHAutumn.133.nc"

# %%
dw_1 = xr.open_dataset(diri+fw_1)
dw_2 = xr.open_dataset(diri+fw_2)
dw_3 = xr.open_dataset(diri+fw_3)
dw_4 = xr.open_dataset(diri+fw_4)
dw_5 = xr.open_dataset(diri+fw_5)

# %%
dw_1 = dw_1.sel(time=slice("1981-01-01","2018-12-31"))
dw_2 = dw_2.sel(time=slice("1981-01-01","2018-12-31"))
dw_3 = dw_3.sel(time=slice("1981-01-01","2018-12-31"))
dw_4 = dw_4.sel(time=slice("1981-01-01","2018-12-31"))
dw_5 = dw_5.sel(time=slice("1981-01-01","2018-12-31"))

# %%
er_active     = xr.where(dw_1["amp"] >= 1, dw_1, np.nan).dropna(dim="time")
kelvin_active = xr.where(dw_2["amp"] >= 1, dw_2, np.nan).dropna(dim="time")
mrg_active    = xr.where(dw_3["amp"] >= 1, dw_3, np.nan).dropna(dim="time")
td_active     = xr.where(dw_4["amp"] >= 1, dw_4, np.nan).dropna(dim="time")
mjo_active    = xr.where(dw_5["amp"] >= 1, dw_5, np.nan).dropna(dim="time")

# %%
tc   = pd.read_csv('/Users/fadhlilrizki/Documents/PhD/thesis/data/TC_dates.csv',
                   usecols=["0"], parse_dates=["0"])

tc_da = xr.DataArray(tc)
er_active         = xr.where(~er_active['time'].isin(tc_da), er_active, np.nan).dropna(dim='time')
mrg_active        = xr.where(~mrg_active['time'].isin(tc_da), mrg_active, np.nan).dropna(dim='time')
kelvin_active     = xr.where(~kelvin_active['time'].isin(tc_da), kelvin_active, np.nan).dropna(dim='time')
td_active         = xr.where(~td_active['time'].isin(tc_da), td_active, np.nan).dropna(dim='time')
mjo_active        = xr.where(~mjo_active['time'].isin(tc_da), mjo_active, np.nan).dropna(dim='time')

# %%
er_wet        = xr.where((er_active["phase"]>=5) & (er_active["phase"]<=7), er_active, np.nan).dropna(dim="time")
kelvin_wet    = xr.where((kelvin_active["phase"]==5), kelvin_active, np.nan).dropna(dim="time")
mrg_wet       = xr.where((mrg_active["phase"]==1) | ((mrg_active["phase"]>=6) & (mrg_active["phase"]<=8)), mrg_active, np.nan).dropna(dim="time")
td_wet        = xr.where(((td_active["phase"]>=6) & (td_active["phase"]<=8)) | (td_active["phase"]==1), td_active, np.nan).dropna(dim="time")
mjo_wet       = xr.where(((mjo_active["phase"]>=4) & (mjo_active["phase"]<=7)), mjo_active, np.nan).dropna(dim="time")

# %%
er_dry        = xr.where(((er_active["phase"]>=1) & (er_active["phase"]<=3)) | (er_active["phase"]==8), er_active, np.nan).dropna(dim="time")
kelvin_dry    = xr.where((kelvin_active["phase"]<=2) | (kelvin_active["phase"]==4) | (kelvin_active["phase"]==8) | (kelvin_active["phase"]==6), kelvin_active, np.nan).dropna(dim="time")
mrg_dry       = xr.where((mrg_active["phase"]==2) | (mrg_active["phase"]==4), mrg_active, np.nan).dropna(dim="time")
td_dry        = xr.where((td_active["phase"]==4), td_active, np.nan).dropna(dim="time")
mjo_dry       = xr.where(((mjo_active["phase"]>=1) & (mjo_active["phase"]<=2)) | (mjo_active["phase"]==8), mjo_active, np.nan).dropna(dim="time")

# %%
er_wet
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 779)
# Coordinates:
#   * time     (time) datetime64[ns] 1981-03-11 1981-03-23 ... 2018-04-21
# Data variables:
#     x        (time) float32 -0.6384 -2.017 -1.992 ... -1.799 -0.9113 0.07632
#     y        (time) float32 1.125 -0.4036 0.4508 1.041 ... 2.212 2.708 2.746
#     amp      (time) float32 1.293 2.057 2.043 1.998 ... 2.811 2.851 2.857 2.747
#     phase    (time) float64 6.0 5.0 5.0 6.0 6.0 6.0 ... 5.0 5.0 6.0 6.0 7.0 7.0

# %%
er_wet
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 779)
# Coordinates:
#   * time     (time) datetime64[ns] 1981-03-11 1981-03-23 ... 2018-04-21
# Data variables:
#     x        (time) float32 -0.6384 -2.017 -1.992 ... -1.799 -0.9113 0.07632
#     y        (time) float32 1.125 -0.4036 0.4508 1.041 ... 2.212 2.708 2.746
#     amp      (time) float32 1.293 2.057 2.043 1.998 ... 2.811 2.851 2.857 2.747
#     phase    (time) float64 6.0 5.0 5.0 6.0 6.0 6.0 ... 5.0 5.0 6.0 6.0 7.0 7.0

# %%
#ER AND KELVIN
er_er_wetwet  = er_wet["time"].dt.strftime("%Y%m%d").to_dataframe(name="date")
er_er_drydry  = er_dry["time"].dt.strftime("%Y%m%d").to_dataframe(name="date")

klv_klv_wetwet  = kelvin_wet["time"].dt.strftime("%Y%m%d").to_dataframe(name="date")
klv_klv_drydry  = kelvin_dry["time"].dt.strftime("%Y%m%d").to_dataframe(name="date")

mrg_mrg_wetwet  = mrg_wet["time"].dt.strftime("%Y%m%d").to_dataframe(name="date")
mrg_mrg_drydry  = mrg_dry["time"].dt.strftime("%Y%m%d").to_dataframe(name="date")

td_td_wetwet  = td_wet["time"].dt.strftime("%Y%m%d").to_dataframe(name="date")
td_td_drydry  = td_dry["time"].dt.strftime("%Y%m%d").to_dataframe(name="date")

mjo_mjo_wetwet  = mjo_wet["time"].dt.strftime("%Y%m%d").to_dataframe(name="date")
mjo_mjo_drydry  = mjo_dry["time"].dt.strftime("%Y%m%d").to_dataframe(name="date")


#ER kelvin
er_klv_wetwet = kelvin_wet["time"].where(er_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
er_klv_drywet = kelvin_wet["time"].where(er_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
er_klv_drydry = kelvin_dry["time"].where(er_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
er_klv_wetdry = kelvin_dry["time"].where(er_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")

#MRG and KELVIN

mrg_klv_wetwet = kelvin_wet["time"].where(mrg_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
mrg_klv_drywet = kelvin_wet["time"].where(mrg_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
mrg_klv_drydry = kelvin_dry["time"].where(mrg_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
mrg_klv_wetdry = kelvin_dry["time"].where(mrg_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")

#TD and Kelvin

td_klv_wetwet  = kelvin_wet["time"].where(td_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
td_klv_drywet  = kelvin_wet["time"].where(td_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
td_klv_drydry  = kelvin_dry["time"].where(td_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
td_klv_wetdry  = kelvin_dry["time"].where(td_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")

#MJO and Kelvin

mjo_klv_wetwet  = kelvin_wet["time"].where(mjo_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
mjo_klv_drywet  = kelvin_wet["time"].where(mjo_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
mjo_klv_drydry  = kelvin_dry["time"].where(mjo_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
mjo_klv_wetdry  = kelvin_dry["time"].where(mjo_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")

# %%
#ER AND MRG
er_mrg_wetwet = mrg_wet["time"].where(er_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
er_mrg_drywet = mrg_wet["time"].where(er_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
er_mrg_drydry = mrg_dry["time"].where(er_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
er_mrg_wetdry = mrg_dry["time"].where(er_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")

# %%
#ER AND TD
er_td_wetwet = td_wet["time"].where(er_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
er_td_drywet = td_wet["time"].where(er_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
er_td_drydry = td_dry["time"].where(er_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
er_td_wetdry = td_dry["time"].where(er_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")

# %%
#ER AND MJO
er_mjo_wetwet = mjo_wet["time"].where(er_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
er_mjo_drywet = mjo_wet["time"].where(er_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
er_mjo_drydry = mjo_dry["time"].where(er_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
er_mjo_wetdry = mjo_dry["time"].where(er_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")

# %%
#mrg AND MJO
mrg_mjo_wetwet = mjo_wet["time"].where(mrg_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
mrg_mjo_drywet = mjo_wet["time"].where(mrg_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
mrg_mjo_drydry = mjo_dry["time"].where(mrg_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
mrg_mjo_wetdry = mjo_dry["time"].where(mrg_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")

# %%
#TD AND MJO
td_mjo_wetwet = mjo_wet["time"].where(td_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
td_mjo_drywet = mjo_wet["time"].where(td_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
td_mjo_drydry = mjo_dry["time"].where(td_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
td_mjo_wetdry = mjo_dry["time"].where(td_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")

# %%
#MRG AND TD
mrg_td_wetwet = td_wet["time"].where(mrg_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
mrg_td_drywet = td_wet["time"].where(mrg_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
mrg_td_drydry = td_dry["time"].where(mrg_dry["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")
mrg_td_wetdry = td_dry["time"].where(mrg_wet["time"]).dt.strftime("%Y%m%d").to_dataframe(name="date")

# %%
er_er_wetwet
# Out:
#                 date
# time
# 1981-03-11  19810311
# 1981-03-23  19810323
# 1981-03-24  19810324
# 1981-03-25  19810325
# 1981-03-26  19810326
# ...              ...
# 2018-04-17  20180417
# 2018-04-18  20180418
# 2018-04-19  20180419
# 2018-04-20  20180420
# 2018-04-21  20180421
#
# [779 rows x 1 columns]

# %%
er_er_wetwet.to_csv(diro+"er_er_wetwet_KY_mam.csv", columns=['date'], index = False)
er_er_drydry.to_csv(diro+"er_er_drydry_KY_mam.csv", columns=['date'], index = False)

er_klv_wetwet.to_csv(diro+"er_klv_wetwet_KY_mam.csv", columns=['date'], index = False)
er_klv_wetdry.to_csv(diro+"er_klv_wetdry_KY_mam.csv", columns=['date'], index = False)
er_klv_drywet.to_csv(diro+"er_klv_drywet_KY_mam.csv", columns=['date'], index = False)
er_klv_drydry.to_csv(diro+"er_klv_drydry_KY_mam.csv", columns=['date'], index = False)

er_mrg_wetwet.to_csv(diro+"er_mrg_wetwet_KY_mam.csv", columns=['date'], index = False)
er_mrg_wetdry.to_csv(diro+"er_mrg_wetdry_KY_mam.csv", columns=['date'], index = False)
er_mrg_drywet.to_csv(diro+"er_mrg_drywet_KY_mam.csv", columns=['date'], index = False)
er_mrg_drydry.to_csv(diro+"er_mrg_drydry_KY_mam.csv", columns=['date'], index = False)

er_td_wetwet.to_csv(diro+"er_td_wetwet_KY_mam.csv", columns=['date'], index = False)
er_td_wetdry.to_csv(diro+"er_td_wetdry_KY_mam.csv", columns=['date'], index = False)
er_td_drywet.to_csv(diro+"er_td_drywet_KY_mam.csv", columns=['date'], index = False)
er_td_drydry.to_csv(diro+"er_td_drydry_KY_mam.csv", columns=['date'], index = False)

er_mjo_wetwet.to_csv(diro+"er_mjo_wetwet_KY_mam.csv", columns=['date'], index = False)
er_mjo_wetdry.to_csv(diro+"er_mjo_wetdry_KY_mam.csv", columns=['date'], index = False)
er_mjo_drywet.to_csv(diro+"er_mjo_drywet_KY_mam.csv", columns=['date'], index = False)
er_mjo_drydry.to_csv(diro+"er_mjo_drydry_KY_mam.csv", columns=['date'], index = False)

klv_klv_wetwet.to_csv(diro+"klv_klv_wetwet_KY_mam.csv", columns=['date'], index = False)
klv_klv_drydry.to_csv(diro+"klv_klv_drydry_KY_mam.csv", columns=['date'], index = False)

mrg_mrg_wetwet.to_csv(diro+"mrg_mrg_wetwet_KY_mam.csv", columns=['date'], index = False)
mrg_mrg_drydry.to_csv(diro+"mrg_mrg_drydry_KY_mam.csv", columns=['date'], index = False)

mrg_klv_wetwet.to_csv(diro+"mrg_klv_wetwet_KY_mam.csv", columns=['date'], index = False)
mrg_klv_wetdry.to_csv(diro+"mrg_klv_wetdry_KY_mam.csv", columns=['date'], index = False)
mrg_klv_drywet.to_csv(diro+"mrg_klv_drywet_KY_mam.csv", columns=['date'], index = False)
mrg_klv_drydry.to_csv(diro+"mrg_klv_drydry_KY_mam.csv", columns=['date'], index = False)

mrg_td_wetwet.to_csv(diro+"mrg_td_wetwet_KY_mam.csv", columns=['date'], index = False)
mrg_td_wetdry.to_csv(diro+"mrg_td_wetdry_KY_mam.csv", columns=['date'], index = False)
mrg_td_drywet.to_csv(diro+"mrg_td_drywet_KY_mam.csv", columns=['date'], index = False)
mrg_td_drydry.to_csv(diro+"mrg_td_drydry_KY_mam.csv", columns=['date'], index = False)

mrg_mjo_wetwet.to_csv(diro+"mrg_mjo_wetwet_KY_mam.csv", columns=['date'], index = False)
mrg_mjo_wetdry.to_csv(diro+"mrg_mjo_wetdry_KY_mam.csv", columns=['date'], index = False)
mrg_mjo_drywet.to_csv(diro+"mrg_mjo_drywet_KY_mam.csv", columns=['date'], index = False)
mrg_mjo_drydry.to_csv(diro+"mrg_mjo_drydry_KY_mam.csv", columns=['date'], index = False)

td_td_wetwet.to_csv(diro+"td_td_wetwet_KY_mam.csv", columns=['date'], index = False)
td_td_drydry.to_csv(diro+"td_td_drydry_KY_mam.csv", columns=['date'], index = False)

td_klv_wetwet.to_csv(diro+"td_klv_wetwet_KY_mam.csv", columns=['date'], index = False)
td_klv_wetdry.to_csv(diro+"td_klv_wetdry_KY_mam.csv", columns=['date'], index = False)
td_klv_drywet.to_csv(diro+"td_klv_drywet_KY_mam.csv", columns=['date'], index = False)
td_klv_drydry.to_csv(diro+"td_klv_drydry_KY_mam.csv", columns=['date'], index = False)

td_mjo_wetwet.to_csv(diro+"td_mjo_wetwet_KY_mam.csv", columns=['date'], index = False)
td_mjo_wetdry.to_csv(diro+"td_mjo_wetdry_KY_mam.csv", columns=['date'], index = False)
td_mjo_drywet.to_csv(diro+"td_mjo_drywet_KY_mam.csv", columns=['date'], index = False)
td_mjo_drydry.to_csv(diro+"td_mjo_drydry_KY_mam.csv", columns=['date'], index = False)



mjo_mjo_wetwet.to_csv(diro+"mjo_mjo_wetwet_KY_mam.csv", columns=['date'], index = False)
mjo_mjo_drydry.to_csv(diro+"mjo_mjo_drydry_KY_mam.csv", columns=['date'], index = False)

mjo_klv_wetwet.to_csv(diro+"mjo_klv_wetwet_KY_mam.csv", columns=['date'], index = False)
mjo_klv_wetdry.to_csv(diro+"mjo_klv_wetdry_KY_mam.csv", columns=['date'], index = False)
mjo_klv_drywet.to_csv(diro+"mjo_klv_drywet_KY_mam.csv", columns=['date'], index = False)
mjo_klv_drydry.to_csv(diro+"mjo_klv_drydry_KY_mam.csv", columns=['date'], index = False)

# %%
er_td_drydry
# Out:
#                 date
# time
# 1981-03-02  19810302
# 1981-04-20  19810420
# 1981-04-29  19810429
# 1981-05-13  19810513
# 1982-03-10  19820310
# ...              ...
# 2016-05-15  20160515
# 2017-03-02  20170302
# 2017-04-08  20170408
# 2018-03-29  20180329
# 2018-04-04  20180404
#
# [84 rows x 1 columns]
